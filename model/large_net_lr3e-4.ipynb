# %%
import numpy as np
import torch
import torch.nn as nn
import torchvision
import os
import json
import time

device='cuda'

# %%
tokens = [
    '<START>', '<END>', '<PAD>', 'measure', 'note', 'pitch', 'step', 'alter',
    'octave', 'duration', 'type', 'rest', 'dot', 'staff', 'notations', 'slur',
    'ff', 'f', 'mf', 'mp', 'p', 'pp', 'backup', 'chord'] + list('ABCDEFG') \
+ ['-1'] + list('0123456789') + ['10', '11', '12', '13', '14', '15', '16'] + ['}'] \
+ ['whole', 'half', 'quarter', 'eighth', '16th']

word_to_ix = {word: i for i, word in enumerate(tokens)}
ix_to_word = {str(i): word for i, word in enumerate(tokens)}
len_lexicon = len(word_to_ix)

# %%
dataset_dir = 'storage/samples/'
lstm_hidden_size = 128
fc1_output_size = 128
seq_len = 64
batch_size = 64

# %%
def get_time_signature_layer(measure_length, height=224, width=224):
    # measure length is 0 for 4/4 and 1 for 3/4
    x = np.zeros((height, width)).astype(np.uint8)
    if measure_length == 12:
        x[:int(height/2)] += 255
    if measure_length == 16:
        x[int(height/2):] += 255
    return x

def get_key_signature_layer(key_number, height=224, width=224):
    # key number is between -7 and 7 inclusive
    x = np.zeros((height, width)).astype(np.uint8)
    splits = np.array_split(x, 15)
    splits[key_number+7] += 255
    return x

# %%
class Dataset():
    def __init__(self, path, seq_len):
        self.seq_len = seq_len
        self.images = np.load(path + 'images.npy')
        self.measure_lengths = np.load(path + 'measure_lengths.npy')
        self.key_numbers = np.load(path + 'key_numbers.npy')
        with open(path + 'pc_data.json') as f:
            self.pc_data = json.load(f)
        self.sequences = []
        self.image_indices = []
        for i, pc in enumerate(self.pc_data):
            if len(pc) < seq_len+1:
                pc = pc + ['<PAD>']*(seq_len+1-len(pc))
            pc_as_ix = np.array([int(word_to_ix[word]) for word in pc])
            for j in range(len(pc)-seq_len):
                self.sequences.append(pc_as_ix[j:j+seq_len+1])
                self.image_indices.append(i)
        self.image_indices = np.array(self.image_indices)
        self.sequences = np.array(self.sequences)
            
    def get_batch(self, batch_size, val=False):
        validation_partition = int(len(self.sequences)*0.9)
        if not val:
            sequence_batch_indices = np.random.choice(len(self.sequences[:validation_partition]), size=batch_size)
        else:
            sequence_batch_indices = np.random.choice(len(self.sequences[validation_partition:]), size=batch_size)
        image_batch_indices = self.image_indices[sequence_batch_indices]
        raw_image_batch = self.images[image_batch_indices].reshape(-1, 1, 224, 224)
        measure_lengths_batch = self.measure_lengths[image_batch_indices]
        key_numbers_batch = self.key_numbers[image_batch_indices]
        measure_lengths_layers = []
        key_numbers_layers = []
        for i in range(batch_size):
            measure_length = measure_lengths_batch[i]
            key_number = key_numbers_batch[i]
            measure_lengths_layers.append(get_time_signature_layer(measure_length))
            key_numbers_layers.append(get_key_signature_layer(key_number))
        measure_lengths_layers = np.array(measure_lengths_layers).reshape(-1, 1, 224, 224)
        key_numbers_layers = np.array(key_numbers_layers).reshape(-1, 1, 224, 224)
        image_batch = np.concatenate([raw_image_batch, measure_lengths_layers, key_numbers_layers], axis=1)
        sequence_batch = self.sequences[sequence_batch_indices]
        image_batch = torch.Tensor(image_batch).type(torch.float).to(device)
        sequence_batch = torch.Tensor(sequence_batch).type(torch.long).to(device)
        return image_batch, sequence_batch, image_batch_indices

# %%
def get_datasets(n):
    all_datasets = os.listdir(dataset_dir)
    dataset_sample = []
    for _ in range(n):
        i = np.random.randint(len(all_datasets))
        filename = all_datasets[i]
        dataset = Dataset(dataset_dir + filename + '/', seq_len)
        dataset_sample.append(dataset)
    return dataset_sample

# %%
class ConvSubunit(nn.Module):
    def __init__(self, input_size, output_size, filter_size, stride, padding, dropout):
        super().__init__()
        self.conv = nn.Conv2d(input_size, output_size, filter_size, stride=stride, padding=padding)
        self.dp = nn.Dropout2d(p=dropout)
        self.bn = nn.BatchNorm2d(output_size)
        self.relu = nn.LeakyReLU()
        self.sequential = nn.Sequential(self.conv, self.dp, self.bn, self.relu)

    def forward(self, x):
        return self.sequential(x)
    
class LargeConvUnit(nn.Module):
    def __init__(self, input_size, output_size, filter_size, stride, padding, dropout):
        super().__init__()
        self.subunit1 = ConvSubunit(input_size, output_size, filter_size, 1, padding, dropout)
        self.subunit2 = ConvSubunit(output_size, output_size, filter_size, 1, padding, dropout)
        self.subunit3 = ConvSubunit(output_size, output_size, filter_size, 1, padding, dropout)
        self.subunit4 = ConvSubunit(output_size, output_size, filter_size, stride, padding, dropout)

    def forward(self, x):
        x = self.subunit1(x)
        cache = x
        x = self.subunit2(x)
        x = self.subunit3(x)
        x = x + cache
        x = self.subunit4(x)
        return x
    
class SmallConvUnit(nn.Module):
    def __init__(self, input_size, output_size, filter_size, stride, padding, dropout):
        super().__init__()
        self.subunit1 = ConvSubunit(input_size, output_size, filter_size, 1, padding, dropout)
        self.subunit2 = ConvSubunit(output_size, output_size, filter_size, stride, padding, dropout)

    def forward(self, x):
        x = self.subunit1(x)
        x = self.subunit2(x)
        return x

# %%
class SmallCNN(nn.Module):
    def __init__(self, output_size):
        super().__init__()
        self.cnn = nn.Sequential(SmallConvUnit(3, 32, 3, 2, 1, 0.1), # (224, 224) --> (112, 112)
                                 SmallConvUnit(32, 64, 3, 2, 1, 0.1), # (112, 112) --> (56, 56)
                                 SmallConvUnit(64, 128, 3, 4, 1, 0.1), # (56, 56) --> (14, 14)
                                 SmallConvUnit(128, 256, 3, 7, 1, 0.1)) # (14, 14) --> (2, 2)
        self.fc = nn.Linear(1024, output_size)
        
    def forward(self, x):
        x = self.cnn(x)
        x = x.view(-1, 1024)
        x = self.fc(x)
        return x
        
class LargeCNN(nn.Module):
    def __init__(self, output_size):
        super().__init__()
        self.cnn = nn.Sequential(LargeConvUnit(3, 32, 3, 2, 1, 0.1), # (224, 224) --> (112, 112)
                                 LargeConvUnit(32, 64, 3, 2, 1, 0.1), # (112, 112) --> (56, 56)
                                 LargeConvUnit(64, 128, 3, 4, 1, 0.1), # (56, 56) --> (14, 14)
                                 LargeConvUnit(128, 256, 3, 7, 1, 0.1)) # (14, 14) --> (2, 2)
        self.fc = nn.Linear(1024, output_size)
        
    def forward(self, x):
        x = self.cnn(x)
        x = x.view(-1, 1024)
        x = self.fc(x)
        return x
        
class SqueezeCNN(nn.Module):
    def __init__(self, output_size):
        super().__init__()
        self.cnn = torchvision.models.squeezenet1_0(pretrained=True)
        self.cnn.classifier[1] = nn.Conv2d(512, output_size, kernel_size=(1,1), stride=(1,1))
        
    def forward(self, x):
        x = self.cnn(x)
        return x

# %%
class Net(nn.Module):
    def __init__(self, save_dir, cnn, len_lexicon, lstm_hidden_size, fc1_output_size, device, num_directions=1):
        super().__init__()
        self.save_dir = save_dir
        self.len_lexicon = len_lexicon
        self.lstm_hidden_size = lstm_hidden_size
        self.fc1_output_size = fc1_output_size
        self.num_directions = num_directions
        self.bidirectional = (num_directions==2)
        self.cnn = cnn
        self.embed = nn.Embedding(num_embeddings=self.len_lexicon, embedding_dim=5)
        self.lstm1 = nn.LSTM(input_size=5,
                             hidden_size=self.lstm_hidden_size,
                             num_layers=2,
                             batch_first=True,
                             dropout=0.3,
                             bidirectional=self.bidirectional)
        self.lstm2 = nn.LSTM(input_size=self.fc1_output_size+self.num_directions*self.lstm_hidden_size,
                             hidden_size=self.lstm_hidden_size,
                             num_layers=2,
                             batch_first=True,
                             dropout=0.3,
                             bidirectional=self.bidirectional)
        self.fc2 = nn.Linear(self.num_directions*self.lstm_hidden_size, self.len_lexicon)
        
    def forward(self, image_input, sequence_input, internal1=None, internal2=None):
        bs = image_input.shape[0]
        sl = sequence_input.shape[1]
        if internal1:
            h1, c1 = internal1
        else:
            h1 = torch.zeros(2*self.num_directions, bs, self.lstm_hidden_size).to(device)
            c1 = torch.zeros(2*self.num_directions, bs, self.lstm_hidden_size).to(device)
        if internal2:
            h2, c2 = internal2
        else:
            h2 = torch.zeros(2*self.num_directions, bs, self.lstm_hidden_size).to(device)
            c2 = torch.zeros(2*self.num_directions, bs, self.lstm_hidden_size).to(device)
        image_output = self.cnn(image_input)
        image_output = image_output.repeat(1, sl).view(bs, sl, self.fc1_output_size)
        sequence_output, (h1, c1) = self.lstm1(self.embed(sequence_input), (h1, c1))
        concatenated = torch.cat([image_output, sequence_output], 2)
        lstm2_out, (h2, c2) = self.lstm2(concatenated, (h2, c2))
        out = self.fc2(lstm2_out)
        return out, (h1, c1), (h2, c2)
    
    def fit(self, iterations, batch_size, optimizer, loss_fn, print_every=100, save_every=5000, train_time=0, past_iterations=0):
        if not os.path.exists(self.save_dir):
            os.mkdir(self.save_dir)
        time_checkpoint = time.time()
        for i in range(iterations):
            self.train()
            if i % 500 == 0:
                dataset = get_datasets(1)[0]
            arr, seq, _ = dataset.get_batch(batch_size)
            seq1 = seq[:, :-1]
            seq2 = seq[:, 1:]
            out, _, _ = self.forward(arr, seq1)
            out = out.view(-1, self.len_lexicon)
            targets = seq2.reshape(-1)
            loss = loss_fn(out, targets)
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            
            
#                 out_val = out_val.cpu().detach().numpy().reshape(64, len_lexicon)
#                 out_val = out_val.argmax(axis=1)
#                 out_val = [ix_to_word[str(x)] for x in out_val]
#                 targets_val = [ix_to_word[str(x)] for x in targets_val.cpu().detach().numpy()]
#                 print('train loss: ', loss)
#                 print('val loss: ', val_loss)
#                 print(out_val)
#                 print(targets_val)
#                 print('----------------------------------------------')
            
            
#             out_simplified = out.cpu().detach().numpy().reshape(64, len_lexicon)
#             out_simplified = out_simplified.argmax(axis=1)
#             out_simplified = [ix_to_word[str(x)] for x in out_simplified]
#             targets_simplified = [ix_to_word[str(x)] for x in targets.cpu().detach().numpy()]
#             print(out_simplified)
#             print(targets_simplified)
#             print('--------------------------')
            
            train_time += time.time() - time_checkpoint
            time_checkpoint = time.time()
            if i % print_every == 0:
                with torch.no_grad():
                    arr_val, seq_val, _ = dataset.get_batch(batch_size, val=True)
                    seq1_val = seq_val[:, :-1]
                    seq2_val = seq_val[:, 1:]
                    out_val, _, _ = self.forward(arr_val, seq1_val)
                    out_val = out_val.view(-1, self.len_lexicon)
                    targets_val = seq2_val.reshape(-1)
                    val_loss = loss_fn(out_val, targets_val)
                arr, _, image_batch_indices = dataset.get_batch(1, val=True)
                pc = dataset.pc_data[image_batch_indices[0]]
                pc = ' '.join(pc)
                pred_seq = self.predict(arr)
                pred_seq = ' '.join(pred_seq)
                pred_seq2 = self.predict_stochastic(arr)
                pred_seq2 = ' '.join(pred_seq2)
                arr_val, _, image_batch_indices = dataset.get_batch(1, val=False)
                true_val = dataset.pc_data[image_batch_indices[0]]
                true_val = ' '.join(true_val)
                pred_val = self.predict(arr_val)
                pred_val = ' '.join(pred_val)
                with open(f'{self.save_dir}log.txt', 'a+') as f:
                    info_string = f"""
                    ----
                    iteration: {i}
                    time elapsed: {train_time}
                    train loss: {loss}
                    val loss: {val_loss}
                    ----
                    pred1: {pred_seq}
                    ----
                    pred2: {pred_seq2}
                    ----
                    true:  {pc}
                    ----
                    pred_val: {pred_val}
                    ----
                    true_val: {true_val}
                    ----



                    """.replace('    ', '')
                    print(info_string)
                    f.write(info_string)
            if i % save_every == 0 and i != 0:
                for param_group in optimizer.param_groups:
                    param_group['lr'] *= 0.99
                torch.save(self.state_dict(), f'{self.save_dir}checkpoint_iteration_{past_iterations+i}.pt')
                with open(f'{self.save_dir}training_info.json', 'w+') as f:
                    json.dump({'train_time': train_time, 'past_iterations': past_iterations+i}, f)
                    
    def resume_fit(self, iterations, optimizer, loss_fn, print_every=100, save_every=5000):
        with open(f'{self.save_dir}training_info.json', 'w+') as f:
            training_info = json.load(f)
        train_time = training_info['train_time']
        past_iterations = training_info['past_iterations']
        checkpoint = torch.load(f'{self.save_dir}checkpoint_iteration_{past_iterations}.pt')
        self.load_state_dict(checkpoint)
        self.fit(iterations, optimizer, loss_fn, print_every=print_every, save_every=save_every, train_time=train_time, past_iterations=past_iterations)
                
             
    def predict(self, arr):
        self.eval()    
        with torch.no_grad():
            arr = arr.view(1,3, 224, 224)
            output_sequence = ['<START>']
            h1 = torch.zeros(2*self.num_directions, 1, self.lstm_hidden_size).to(device)
            c1 = torch.zeros(2*self.num_directions, 1, self.lstm_hidden_size).to(device)
            h2 = torch.zeros(2*self.num_directions, 1, self.lstm_hidden_size).to(device)
            c2 = torch.zeros(2*self.num_directions, 1, self.lstm_hidden_size).to(device)
            while output_sequence[-1] != '<END>' and len(output_sequence)<400:
                sequence_input = torch.Tensor([word_to_ix[output_sequence[-1]]]).type(torch.long).view(1, 1).to(device)
                out, (h1, c1), (h2, c2) = self.forward(arr, sequence_input, (h1, c1), (h2, c2))
                _, sequence_input = out[0, 0, :].max(0)
                output_sequence.append(ix_to_word[str(sequence_input.item())])
        self.train()
        return output_sequence
    
    def predict_stochastic(self, arr):
        self.eval()    
        with torch.no_grad():
            arr = arr.view(1,3, 224, 224)
            output_sequence = ['<START>']
            h1 = torch.zeros(2*self.num_directions, 1, self.lstm_hidden_size).to(device)
            c1 = torch.zeros(2*self.num_directions, 1, self.lstm_hidden_size).to(device)
            h2 = torch.zeros(2*self.num_directions, 1, self.lstm_hidden_size).to(device)
            c2 = torch.zeros(2*self.num_directions, 1, self.lstm_hidden_size).to(device)
            while output_sequence[-1] != '<END>' and len(output_sequence)<400:
                sequence_input = torch.Tensor([word_to_ix[output_sequence[-1]]]).type(torch.long).view(1, 1).to(device)
                out, (h1, c1), (h2, c2) = self.forward(arr, sequence_input, (h1, c1), (h2, c2))
                log_probs = out[0, 0, :].cpu().numpy()
                probs = np.exp(log_probs) / np.exp(log_probs).sum()
                predicted_ix = np.random.choice(len_lexicon, p=probs)
                output_sequence.append(ix_to_word[str(predicted_ix)])
        self.train()
        return output_sequence

# %%
large_cnn = LargeCNN(fc1_output_size).to(device)
large_loss_fn = nn.CrossEntropyLoss()
large_net = Net(f'storage/large_model_lr3e-4/', large_cnn, len_lexicon, lstm_hidden_size, fc1_output_size, device).to(device)
large_optimizer = torch.optim.Adam(large_net.parameters(), lr=3e-4)

# %%
large_net.fit(500000, batch_size, large_optimizer, large_loss_fn)
# Out:
# ----
# iteration: 0
# time elapsed: 3.946277141571045
# train loss: 4.016635417938232
# val loss: 3.957077741622925
# ----
# pred1: <START> alter staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff
# ----
# pred2: <START> G 10 12 half <PAD> <END>
# ----
# true:  <START> measure note pitch A -1 5 } duration 8 } type half } staff 1 } } note pitch C 1 6 } duration 8 } type half } staff 1 } } backup duration 16 } } note pitch F -1 2 } duration 4 } type quarter } staff 2 } } note pitch A -1 2 } duration 4 } type quarter } staff 2 } } note pitch G -1 2 } duration 4 } type quarter } staff 2 } } note pitch A 0 2 } duration 4 } type quarter } staff 2 } } } <END>
# ----
# pred_val: <START> alter staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff staff
# ----
# true_val: <START> measure p } note pitch B 0 4 } duration 4 } type quarter } staff 1 } } pp } note pitch F 1 5 } duration 4 } type quarter } staff 1 } } note pitch F 1 5 } duration 8 } type half } staff 1 } } backup duration 16 } } note pitch G -1 2 } duration 8 } type half } staff 2 } } note pitch B -1 2 } duration 4 } type quarter } staff 2 } } note pitch G 0 2 } duration 4 } type quarter } staff 2 } } } <END>
# ----
#
#
#
#
#
# ----
# iteration: 100
# time elapsed: 49.17602205276489
# train loss: 2.722550392150879
# val loss: 2.6905317306518555
# ----
# pred1: <START> } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } }
# ----
# pred2: <START> type staff duration backup } quarter -1 } 0 type } duration D F <END>
# ----
# true:  <START> measure note pitch F -1 5 } duration 4 } type quarter } staff 1 } } p } note pitch C -1 6 } duration 4 } type quarter } staff 1 } } note pitch B -1 5 } duration 4 } type quarter } staff 1 } } backup duration 12 } } note pitch C 1 4 } duration 4 } type quarter } staff 2 } } note pitch D -1 4 } duration 4 } type quarter } staff 2 } } note pitch D 0 4 } duration 4 } type quarter } staff 2 } } } <END>
# ----
# pred_val: <START> } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } }
# ----
# true_val: <START> measure note pitch E 0 4 } duration 4 } type quarter } staff 1 } } note pitch D 0 4 } duration 4 } type quarter } staff 1 } } note pitch G 1 3 } duration 4 } type quarter } staff 1 } } note pitch C -1 4 } duration 4 } type quarter } staff 1 } } backup duration 16 } } note pitch A 1 2 } duration 8 } type half } staff 2 } } note pitch D 0 2 } duration 8 } type half } staff 2 } } } <END>
# ----
# ----
# iteration: 200
# time elapsed: 94.60824656486511
# train loss: 2.678738832473755
# val loss: 2.6968765258789062
# ----
# pred1: <START> } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } }
# ----
# pred2: <START> 8 quarter 1 1 } } <PAD> 2 pitch note } 4 } type type note E 8 B 1 B 3 } 1 D } whole } 12 1 staff note 10 } } 1 4 half } } C 2 1 2 2 } } staff duration } } } quarter duration half 4 1 } } duration } 1 } } } duration note 3 pitch 4 quarter note quarter } 4 } 2 } backup 8 } quarter B } staff } 4 } 4 } } 1 duration } } } duration staff B 1 } } type } quarter } } type note duration } } } } } <PAD> -1 16 pitch D } 4 note } } 3 note note pitch 1 } staff } -1 2 4 1 backup type type duration type 8 } type 5 -1 } duration note type } f <PAD> staff } F duration note } } } } type } 2 type } } quarter 8 } pitch 8 note duration } } 4 staff } } half duration } staff duration duration 1 duration } staff 8 4 pitch } } quarter } staff D staff 5 } duration pitch quarter } C type 1 } note half } 4 backup p E quarter pitch } note } 4 8 } 4 5 0 4 } 1 2 note } note 5 duration } F 8 type } } 1 duration } 0 pitch } } -1 3 } pitch F 1 E 4 } quarter } A duration duration <PAD> staff 2 staff 4 } B staff pitch } } type } 4 1 } staff duration type } 16 } 2 staff 3 } 8 } 4 } duration pitch } } 2 4 note } 8 C quarter duration mp } type duration 16 } } } } } } 5 pitch A } 2 } staff note 1 } 2 } 8 type -1 note } note half 4 } duration } C } 2 } 4 4 type <PAD> } } 4 C B } duration note E } 1 } staff duration 12 type quarter staff note } quarter } } pitch staff } } } 4 } } pitch type } } } note pitch type } 1 1 } } 4 } 4 } 4
# ----
# true:  <START> measure note pitch F 0 4 } duration 8 } type half } staff 1 } } mf } note pitch B 1 4 } duration 4 } type quarter } staff 1 } } backup duration 12 } } note pitch E 1 3 } duration 8 } type half } staff 2 } } note pitch E -1 3 } duration 4 } type quarter } staff 2 } } } <END>
# ----
# pred_val: <START> } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } }
# ----
# true_val: <START> measure note pitch B -1 4 } duration 8 } type half } staff 1 } } note pitch B 1 4 } duration 4 } type quarter } staff 1 } } note pitch B 1 4 } duration 4 } type quarter } staff 1 } } backup duration 16 } } note pitch E 0 2 } duration 8 } type half } staff 2 } } note pitch F 0 2 } duration 4 } type quarter } staff 2 } } note pitch C -1 3 } duration 4 } type quarter } staff 2 } } } <END>
# ----
#
#
#
#
#
# ----
# iteration: 300
# time elapsed: 141.38955855369568
# train loss: 2.3464932441711426
# val loss: 2.3630316257476807
# ----
# pred1: <START> } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } }
# ----
# pred2: <START> 12 type F } quarter 8 note } } } } } A quarter 8 0 3 C C 0 staff } staff } type } backup } pitch 0 2 4 type type half } } type } } 2 A note note quarter eighth 3 -1 } half staff 4 8 type } } } } } quarter staff 4 note 13 duration 0 pitch duration duration } type } } } } 5 type 8 pitch } backup quarter } } } } } backup D -1 half D quarter duration 4 12 half } staff } 2 } } } pitch pitch } 3 } duration 12 } 11 F note duration quarter } } half } type half 4 note 4 0 } } duration 3 } } } } duration 4 4 0 1 note duration 4 } type quarter B } staff note staff } } E F G D } } duration } } duration type staff note type 1 quarter A staff } } E } } staff } note note duration duration duration 2 quarter } } } } } } } note type C 1 } -1 1 0 } } } } } } duration } note 4 C G <PAD> staff 4 duration 8 type 1 } quarter staff type staff } } 4 5 } staff pitch A pitch } note 2 } } } quarter 1 half A 16 quarter <PAD> type } } 1 } } staff backup duration 2 pitch duration 3 } type } type } } } measure pitch 2 5 duration C 8 } } } staff quarter } type } backup staff 0 pitch } 0 } 4 } } quarter duration } 0 8 quarter } duration pitch type type 1 } 2 duration 1 staff } } -1 } A 4 F } quarter } 4 quarter } quarter staff } } } type 0 } } 5 type } } pitch type type } duration quarter quarter 8 staff } } 16 pitch } staff note } pitch 9 duration 1 backup note 4 duration } 5 } staff } } 2 } } staff note type half } pitch } 4 } } 2 pitch quarter pitch duration } 2 4 0 } duration 3 type } G staff type } duration } note
# ----
# true:  <START> measure note pitch F -1 5 } duration 4 } type quarter } staff 1 } } p } note pitch C -1 6 } duration 4 } type quarter } staff 1 } } note pitch B -1 5 } duration 4 } type quarter } staff 1 } } backup duration 12 } } note pitch C 1 4 } duration 4 } type quarter } staff 2 } } note pitch D -1 4 } duration 4 } type quarter } staff 2 } } note pitch D 0 4 } duration 4 } type quarter } staff 2 } } } <END>
# ----
# pred_val: <START> } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } } }
# ----
# true_val: <START> measure pp } note pitch E -1 4 } duration 8 } type half } staff 1 } } note pitch D 0 4 } duration 8 } type half } staff 1 } } backup duration 16 } } note pitch D -1 3 } duration 4 } type quarter } staff 2 } } note pitch B 0 2 } duration 4 } type quarter } staff 2 } } note pitch E 1 3 } duration 8 } type half } staff 2 } } } <END>
# ----
#
#
#
#
#
# ----
# iteration: 400
# time elapsed: 188.15738439559937
# train loss: 1.6945041418075562
# val loss: 1.6687359809875488
# ----
# pred1: <START> } } pitch pitch pitch -1 } } } } } } note pitch pitch pitch } } } pitch pitch pitch -1 } } duration } } type } } } note pitch pitch -1 } } duration } } type } } } pitch pitch pitch -1 } } } } } } pitch pitch pitch 0 } } } duration note pitch pitch } } duration } } note pitch pitch 0 } } duration } } } } pitch pitch pitch -1 } } duration } } type } } } pitch pitch pitch -1 } } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } } duration } } } } } pitch pitch pitch -1 } }
# ----
# pred2: <START> 0 3 pitch 5 } } 4 } backup 1 } note pitch note } 4 } } duration duration note note 3 } duration } type type 1 staff staff half } } } note pitch pitch 16 } } 4 } note note 1 mf } type duration } } type quarter quarter 2 } } pitch C 2 -1 4 } 2 duration } 8 } } quarter } } } pitch 0 12 4 3 } duration type 8 4 type quarter staff 2 2 staff staff staff staff } 2 } } backup note 1 0 3 } 4 8 p } half type backup } } 3 backup note <PAD> 1 2 } } D -1 note } duration duration duration type type type 1 2 } staff staff staff } C -1 2 pitch 0 } } } 2 } } } } pitch A -1 0 } } 4 4 type quarter quarter 2 2 } } staff 2 } note pitch 6 2 } } duration type type type } staff staff staff } } note pitch pitch -1 } } } } 4 } pitch pitch F } } duration pitch B pitch } 16 } D type half staff quarter staff } } 3 } note pitch } -1 note <PAD> } 4 duration 8 note } staff } duration } } } 16 pitch eighth 2 1 4 5 } } 8 } 4 quarter } } } 1 0 3 3 } } pitch type pitch pitch } mf } D } type 2 } } } G C pitch 0 2 2 type } 4 } type } } } staff } B 12 pitch 0 4 0 } } } } } quarter } note pitch pitch D 0 4 duration duration } 4 type } } } staff } 1 note C note F 2 duration duration 4 } half type type 2 } quarter type staff 2 1 backup -1 note pitch } pitch 2 quarter } 2 half 2 2 } 1 } } } note C A 0 2 } } } } type } note } B <PAD> 16 } alter 1 3 -1 } } } duration staff 8 D } staff } } E F note type } D duration } type 4 } } 2 }
# ----
# true:  <START> measure note pitch G 0 5 } duration 4 } type quarter } staff 1 } } note pitch G 0 5 } duration 4 } type quarter } staff 1 } } note pitch F 0 5 } duration 4 } type quarter } staff 1 } } backup duration 12 } } note pitch C 1 3 } duration 8 } type half } staff 2 } } note pitch E 0 3 } duration 4 } type quarter } staff 2 } } } <END>
# ----
# pred_val: <START> } pitch pitch pitch <PAD> } } pitch <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# ----
# true_val: <START> measure f } note pitch F 1 5 } duration 4 } type quarter } staff 1 } } note pitch F 0 5 } duration 4 } type quarter } staff 1 } } backup duration 8 } } note pitch C -1 3 } duration 8 } type half } staff 2 } } } <END>
# ----
# ----
# iteration: 500
# time elapsed: 237.16799211502075
# train loss: 1.3903553485870361
# val loss: 1.3579719066619873
# ----
# pred1: <START> } pitch -1 -1 5 } duration 4 } type type } staff staff 1 } } note pitch pitch 1 } } duration note pitch pitch } duration duration } } type } } } } note pitch pitch 0 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type
# ----
# pred2: <START> 11 5 F } duration } } } } duration pitch F A } duration duration type } type quarter } } staff 1 } note } A G 16 } } } } note 12 pitch C 4 } } <PAD> duration 11 C 3 } } duration note B rest 5 3 duration 4 } type quarter type 2 half staff } } } } note E <PAD> 0 } F -1 2 2 4 duration 4 } type type quarter staff quarter 2 2 } } pitch } pitch 0 -1 3 note duration 4 type type half type type 2 } quarter 2 1 } } note pitch alter 3 } pitch G pitch pitch } duration quarter 3 } } quarter staff } } } pitch C A 0 1 } duration duration type } type staff } staff staff 2 } note pitch pitch 0 3 } duration 4 type 4 8 2 staff 2 staff 2 2 half staff 1 2 } 1 1 quarter staff 1 2 staff 2 staff } 1 2 } } } } pitch note note -1 3 } duration 8 } type } quarter staff 2 } } note 16 0 0 2 } } duration } type type quarter } } 2 } note backup D p } } pitch pitch 2 pitch 2 duration duration 4 } type half } } 2 } } note pitch 1 1 3 } duration 4 } type quarter } staff staff } } note note pitch -1 2 -1 } } duration type 2 } staff 1 2 1 } 2 note pitch A } } duration } type type duration } staff } } } note note 1 1 5 } duration } } 4 half } } } pitch D 1 1 5 } duration } 8 type half quarter } staff staff } } note } 1 -1 C 4 } duration } quarter type type } staff 2 } } } pitch pitch G 0 2 duration duration duration type type half type staff staff } staff staff } } note pitch D <PAD> 2 } note duration -1 } pitch duration 4 type staff staff staff 2 staff 2 2 } } } note } 16 F 0 4 } duration 4 8 } quarter type 2 } staff 2 } }
# ----
# true:  <START> measure note pitch C -1 4 } duration 4 } type quarter } staff 1 } } mf } note pitch G -1 3 } duration 4 } type quarter } staff 1 } } mf } note pitch G 1 3 } duration 4 } type quarter } staff 1 } } note pitch A -1 3 } duration 4 } type quarter } staff 1 } } backup duration 16 } } note pitch C 1 3 } duration 8 } type half } staff 2 } } note pitch B 0 2 } duration 8 } type half } staff 2 } } note chord } pitch D 1 3 } duration 8 } type half } staff 2 } } } <END>
# ----
# pred_val: <START> } pitch -1 -1 5 } duration 4 } type type } staff staff 1 } } note pitch pitch 1 } } duration note pitch pitch } duration duration } } type } } } } note pitch pitch 0 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type } } staff } } } pitch pitch 0 -1 3 } duration 4 } type
# ----
# true_val: <START> measure note pitch A 1 5 } duration 4 } type quarter } staff 1 } } note pitch B 0 5 } duration 4 } type quarter } staff 1 } } mp } note pitch A 0 5 } duration 4 } type quarter } staff 1 } } note pitch F 0 5 } duration 4 } type quarter } staff 1 } } backup duration 16 } } note pitch D 0 3 } duration 8 } type half } staff 2 } } note chord } pitch G 1 3 } duration 8 } type half } staff 2 } } note pitch C 1 3 } duration 8 } type half } staff 2 } } } <END>
# ----
#
#
#
#
#
# ----
# iteration: 600
# time elapsed: 284.16980361938477
# train loss: 0.9826364517211914
# val loss: 1.049194097518921
# ----
# pred1: <START> 1 1 1 } } note pitch pitch -1 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type
# ----
# pred2: <START> 1 1 B 1 3 duration } 8 8 } quarter half half } } } B chord pitch pitch 2 } duration 4 } } type } 1 } } note note F 1 } } 4 } } F pitch pitch -1 0 } duration } } type quarter } 1 } } note pitch F <PAD> } } note note -1 E 3 } duration 4 type type } } staff 2 } } note <PAD> pitch 1 1 1 } } } } C C 3 5 3 3 duration } } } } 2 } note note 16 2 } duration 4 type type } } staff 2 } } note chord duration <PAD> 3 6 duration 4 type type quarter staff 1 2 staff 2 2 } } } } pitch pitch } 0 3 3 } duration 8 } type 4 half half staff 2 } staff } } } } ff A 0 E 4 } duration 4 } } } } } 2 note pitch 3 3 } 4 4 8 type } } staff 2 } } note duration chord 2 4 duration 8 4 } } quarter } staff } } duration duration 0 } } note duration pitch 2 } duration 8 } type type staff staff staff 2 } } } note pitch C 3 3 } duration 4 } type type } } 1 } } note } pitch 16 3 4 } duration 4 type type half staff staff staff 2 2 2 } } staff } note pitch pitch pitch } } duration duration } } } quarter } } note p G 1 4 } duration 4 } type quarter quarter staff staff } } } note pitch C D } } note pitch C <PAD> 3 duration 4 } type type quarter staff } 2 } } note duration <PAD> } } pitch E 0 1 } } duration duration 4 } type half } staff 2 } } } } G pitch G -1 2 } duration 4 } type quarter } } staff } } backup } G G 0 5 } 8 4 } } } quarter 2 4 note duration } } duration pitch pitch D 2 5 duration duration } type type quarter 2 staff 2 2 } } } } note B 2 0 2
# ----
# true:  <START> measure mf } note pitch G -1 4 } duration 4 } type quarter } staff 1 } } note pitch A -1 4 } duration 4 } type quarter } staff 1 } } note pitch E 1 5 } duration 4 } type quarter } staff 1 } } note pitch A 0 5 } duration 4 } type quarter } staff 1 } } backup duration 16 } } note pitch E 1 2 } duration 4 } type quarter } staff 2 } } note pitch G -1 2 } duration 4 } type quarter } staff 2 } } note pitch D -1 2 } duration 8 } type half } staff 2 } } note chord } pitch G 1 2 } duration 8 } type half } staff 2 } } } <END>
# ----
# pred_val: <START> } pitch pitch -1 -1 5 } duration 4 } type quarter } staff 1 } } note pitch pitch 1 } } duration duration 4 } type quarter } staff 1 } } note pitch pitch 1 } } duration duration 4 } type quarter } staff 1 } } note pitch pitch 1 } } duration duration 4 } type quarter } staff 1 } } note pitch pitch 1 } } duration duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type
# ----
# true_val: <START> measure note pitch E -1 4 } duration 4 } type quarter } staff 1 } } note pitch F 0 4 } duration 4 } type quarter } staff 1 } } note pitch F 0 4 } duration 4 } type quarter } staff 1 } } backup duration 12 } } note pitch E -1 3 } duration 4 } type quarter } staff 2 } } note chord } pitch G 1 3 } duration 4 } type quarter } staff 2 } } note chord } pitch B 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note chord } pitch G -1 3 } duration 4 } type quarter } staff 2 } } note chord } pitch C 0 4 } duration 4 } type quarter } staff 2 } } note pitch F 1 3 } duration 4 } type quarter } staff 2 } } } <END>
# ----
# ----
# iteration: 700
# time elapsed: 331.08369636535645
# train loss: 0.7343766093254089
# val loss: 0.7634218335151672
# ----
# pred1: <START> pitch pitch -1 -1 4 } duration 4 } type quarter } staff 1 } } note duration 16 } } note pitch pitch 1 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type
# ----
# pred2: <START> 8 duration 4 4 } 8 type } } 1 } } } chord note E 6 4 } duration 4 } type } } 1 1 } note pitch 16 } 5 duration 8 4 type type } quarter staff staff staff } } duration quarter duration pitch note note 2 } duration 4 } type type } staff 2 1 } } note chord } F 6 2 } duration 8 } } type } } 2 } note chord } note note 3 6 } duration 4 } } half 2 } note note 5 } } A 3 } type quarter staff staff staff 2 } } } note } note pitch B 5 3 } duration 4 } type 2 } staff 2 } } note } } C F F 0 3 } duration 4 } } type } staff } } backup pitch C -1 3 } duration 4 } type quarter } staff 2 } } note pitch 12 -1 -1 3 duration duration 4 type type type staff staff } 2 2 } } note pitch 16 1 2 duration duration } } type half } 2 } } } 8 chord 1 E pitch 2 } duration 4 } type half } staff 2 } } note chord 4 E } } note duration duration duration 4 } type quarter type staff staff staff 2 } } } backup note 16 1 } } note pitch pitch -1 3 } duration } } type type } 2 2 } } note pitch } -1 1 5 } duration 8 } type quarter } staff staff } } } note C C F 0 3 } duration 4 } type } staff } 1 } } duration pitch pitch -1 5 } } 4 } type quarter } staff 2 } } note pitch G } 5 } } 8 } quarter quarter } 2 } note duration 0 } } duration 4 } } quarter staff } } note } note A -1 3 } duration 3 type type } } staff 2 } } pitch pitch 0 0 5 } 4 4 } type type } staff staff } } note chord 16 } } pitch 12 C 1 } duration } 4 } type half } 2 } } note note pitch 0 4 } duration 4
# ----
# true:  <START> measure p } note pitch E 0 4 } duration 4 } type quarter } staff 1 } } note pitch D -1 4 } duration 4 } type quarter } staff 1 } } f } note pitch E 1 4 } duration 4 } type quarter } staff 1 } } backup duration 12 } } note pitch E 1 2 } duration 8 } type half } staff 2 } } note chord } pitch G 1 2 } duration 8 } type half } staff 2 } } note chord } pitch D 0 3 } duration 8 } type half } staff 2 } } note pitch G 1 2 } duration 4 } type quarter } staff 2 } } } <END>
# ----
# pred_val: <START> pitch pitch -1 -1 4 } duration 4 } type quarter } staff 1 } } note duration 16 } } note pitch pitch 1 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type quarter } staff 2 } } note pitch pitch 0 3 } duration 4 } type
# ----
# true_val: <START> measure note pitch D -1 4 } duration 4 } type quarter } staff 1 } } note pitch B -1 3 } duration 4 } type quarter } staff 1 } } note pitch G 0 3 } duration 4 } type quarter } staff 1 } } note pitch G 0 3 } duration 4 } type quarter } staff 1 } } backup duration 16 } } note pitch B -1 2 } duration 4 } type quarter } staff 2 } } note pitch C 1 3 } duration 4 } type quarter } staff 2 } } note pitch C 1 3 } duration 8 } type half } staff 2 } } } <END>
# ----
#
#
#
#
#
# ----
# iteration: 800
# time elapsed: 377.8499209880829
# train loss: 0.6063564419746399
# val loss: 0.6473060250282288
# ----
# pred1: <START> pitch G -1 4 } duration 4 } type quarter } staff 1 } } backup duration 16 } } note pitch C 1 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter
# ----
# pred2: <START> B F 0 4 } duration 4 quarter type } } staff 1 } backup backup 16 1 } duration 4 duration type quarter } staff staff 1 } } backup pitch B 1 5 } duration 4 } type quarter } staff 1 } } mp } pitch pitch B -1 5 3 } 4 } type quarter } staff 1 } } backup note A -1 4 } duration 4 } type quarter } 1 1 } } backup duration 1 } } note pitch -1 A 5 2 duration 4 } type quarter } staff 2 } } note } pitch D 0 3 8 duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 8 } } quarter } 2 } duration } } pitch pitch E 1 3 } duration 8 } type quarter 2 staff staff staff staff 2 } staff 2 } } note chord } D pitch 0 3 } } 8 } type half } 2 } } note pitch A 0 3 } duration 4 } type quarter } staff 2 } } note chord } pitch C 0 3 } duration 8 } type half } staff 2 } } note chord } pitch E -1 3 } duration 4 } type } } staff 2 } mf pitch } chord note D 4 } duration 8 } type quarter } } 2 } note duration duration } } duration 4 } type } } 1 } } pitch pitch B 1 5 } duration 4 } type half } staff 2 } } note pitch A 0 4 } duration 8 } type } } staff 2 } } pitch chord 4 -1 } } duration 4 } type quarter } staff 2 } 2 note } } note E G 1 2 } duration 8 } type quarter } staff 2 } } backup D B -1 3 } duration 8 } type quarter } staff 2 } } note chord } pitch D 0 2 } duration 4 } quarter half staff 2 } } note pitch duration 1 4 } duration 4 } type half } 2 2 } } note chord } pitch A 1 2 } duration 8 } type quarter } staff 2 } } note pitch F 0 3 } duration 8 }
# ----
# true:  <START> measure mp } note pitch F 1 4 } duration 4 } type quarter } staff 1 } } p } note pitch E 0 4 } duration 4 } type quarter } staff 1 } } ff } note pitch A 0 3 } duration 4 } type quarter } staff 1 } } backup duration 12 } } note pitch A -1 2 } duration 4 } type quarter } staff 2 } } note chord } pitch C 1 3 } duration 4 } type quarter } staff 2 } } note pitch G 1 2 } duration 4 } type quarter } staff 2 } } note pitch B -1 2 } duration 4 } type quarter } staff 2 } } note chord } pitch F 0 3 } duration 4 } type quarter } staff 2 } } } <END>
# ----
# pred_val: <START> pitch G -1 4 } duration 4 } type quarter } staff 1 } } note pitch B 0 4 } duration 4 } type quarter } staff 1 } } backup duration 16 } } note pitch C 1 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter
# ----
# true_val: <START> measure note pitch F 1 5 } duration 4 } type quarter } staff 1 } } p } note pitch G 0 5 } duration 4 } type quarter } staff 1 } } note pitch E 0 5 } duration 4 } type quarter } staff 1 } } note pitch B 1 5 } duration 4 } type quarter } staff 1 } } backup duration 16 } } note pitch G -1 3 } duration 4 } type quarter } staff 2 } } note pitch B 0 3 } duration 4 } type quarter } staff 2 } } note chord } pitch F 1 4 } duration 4 } type quarter } staff 2 } } note pitch A 0 3 } duration 4 } type quarter } staff 2 } } note chord } pitch D 1 4 } duration 4 } type quarter } staff 2 } } note pitch F -1 4 } duration 4 } type quarter } staff 2 } } } <END>
# ----
# ----
# iteration: 900
# time elapsed: 424.67478680610657
# train loss: 0.5196275115013123
# val loss: 0.5637938976287842
# ----
# pred1: <START> pitch G -1 4 } duration 4 } type quarter } staff 1 } } note pitch B 0 4 } duration 4 } type quarter } staff 1 } } backup duration 16 } } note pitch C 1 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter
# ----
# pred2: <START> pitch rest -1 3 } duration duration 4 } type quarter } staff 1 } } note pitch E -1 4 5 duration 4 } } type } staff 1 } } duration } note -1 1 6 } duration 4 } type quarter } staff 1 } } backup duration 12 } } note pitch G B 3 } duration 8 } type quarter } staff 2 } } note pitch A 1 3 } duration 8 } type quarter } staff 2 } } note chord } pitch E 1 2 } duration 8 } type quarter } staff 2 } } note pitch E 1 2 duration duration 4 } type half } staff 2 } } note chord } pitch B 1 2 } duration 16 4 type half } staff 1 1 } } note pitch C 0 3 } duration 8 } type half } staff 2 } } note chord } note C 0 3 } duration 4 } type half } staff 2 } } note chord } pitch F -1 2 } duration 4 } type quarter } staff 2 } } note pitch E 0 3 } duration } } type quarter half staff 2 } } } note note D 16 } } note pitch pitch E 5 } duration 4 } quarter half } 2 } } } chord pitch D 3 3 } duration 8 } type quarter } staff 2 } } note } } } E D B 0 2 } duration 4 } type half } staff 2 } } note <PAD> } note mf 0 3 } } duration 8 } type half } staff 2 } } 2 note } } } pitch G mf <PAD> 2 } duration duration } half quarter } staff 2 } } note pitch A 0 } } duration 4 } type quarter } staff 2 } } note pitch G 1 4 } duration 4 } type quarter } staff 2 } } note <END>
# ----
# true:  <START> measure note pitch F -1 4 } duration 4 } type quarter } staff 1 } } mp } note pitch F 0 4 } duration 4 } type quarter } staff 1 } } note pitch F 0 4 } duration 4 } type quarter } staff 1 } } note pitch C 0 4 } duration 4 } type quarter } staff 1 } } backup duration 16 } } note pitch B 1 3 } duration 8 } type half } staff 2 } } note pitch F -1 4 } duration 4 } type quarter } staff 2 } } note pitch D 0 4 } duration 4 } type quarter } staff 2 } } } <END>
# ----
# pred_val: <START> pitch G -1 4 } duration 4 } type quarter } staff 1 } } note pitch B 0 4 } duration 4 } type quarter } staff 1 } } backup duration 16 } } note pitch C 1 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter } staff 2 } } note pitch C 0 3 } duration 4 } type quarter
# ----
# true_val: <START> measure note pitch E -1 5 } duration 4 } type quarter } staff 1 } } p } note pitch F -1 5 } duration 4 } type quarter } staff 1 } } note pitch C 1 5 } duration 4 } type quarter } staff 1 } } p } note pitch F 0 4 } duration 4 } type quarter } staff 1 } } backup duration 16 } } note pitch E 1 2 } duration 8 } type half } staff 2 } } note pitch E 1 2 } duration 4 } type quarter } staff 2 } } note pitch C -1 2 } duration 4 } type quarter } staff 2 } } note chord } pitch E -1 2 } duration 4 } type quarter } staff 2 } } } <END>
# ----

# %%
# for lr in np.linspace(1e-5, 1e-4, 5):
#     small_cnn = SmallCNN(fc1_output_size).to(device)
#     small_loss_fn = nn.CrossEntropyLoss()
#     small_net = Net(f'storage/small_model_learning_rate_testing/{lr}/', small_cnn, len_lexicon, lstm_hidden_size, fc1_output_size, device).to(device)
#     small_optimizer = torch.optim.Adam(small_net.parameters(), lr=lr)
#     small_net.fit(1000, batch_size, small_optimizer, small_loss_fn)
